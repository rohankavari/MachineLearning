# %% [markdown]
# <a href="https://colab.research.google.com/github/rohankavari/MachineLearning/blob/main/regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.formula.api import ols
import statsmodels.api as sm
import pandas.util.testing as tm
import seaborn as sns

# %%
df=pd.read_excel("/content/drive/MyDrive/dataset/Real estate valuation data set.xlsx")
df.drop([0],inplace=True)

# %%
df['logX2']=np.log(df['X2'])
df['logX3']=np.log(df['X3'])
df['logY']=np.log(df['Y'])

df.replace([np.inf, -np.inf], np.nan, inplace=True)
df.dropna(inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py:726: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
df.describe()
# Out:
#                 X1          X2           X3  ...       logX2       logX3        logY
# count   395.000000  395.000000   395.000000  ...  395.000000  395.000000  395.000000
# mean   2013.154430   18.456203  1124.259031  ...    2.669730    6.436737    3.546059
# std       0.281111   11.014399  1278.253478  ...    0.800454    1.124729    0.385494
# min    2012.666667    1.000000    23.382840  ...    0.000000    3.152002    2.028148
# 25%    2012.916667   10.750000   297.959750  ...    2.374635    5.696538    3.295837
# 50%    2013.166667   16.300000   519.461700  ...    2.791165    6.252793    3.632309
# 75%    2013.416667   29.200000  1525.981500  ...    3.374163    7.330221    3.827553
# max    2013.583333   43.800000  6488.021000  ...    3.779634    8.777713    4.360548
#
# [8 rows x 10 columns]

# %%
plt.figure(figsize=(12, 12))
sns.heatmap(df.corr(),annot=True)

# %%
pp = sns.pairplot(data=df,y_vars=['Y'])

# %%
pp = sns.pairplot(data=df,y_vars=['logY'])

# %%
mod = ols("Y~X2+X3+X3+X4+X5+X6",data=df)
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      Y   R-squared:                       0.625
# Model:                            OLS   Adj. R-squared:                  0.620
# Method:                 Least Squares   F-statistic:                     129.6
# Date:                Thu, 22 Apr 2021   Prob (F-statistic):           1.53e-80
# Time:                        10:14:19   Log-Likelihood:                -1369.6
# No. Observations:                 395   AIC:                             2751.
# Df Residuals:                     389   BIC:                             2775.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   -1.02e+04   5559.657     -1.834      0.067   -2.11e+04     735.526
# X2            -0.2000      0.036     -5.565      0.000      -0.271      -0.129
# X3            -0.0032      0.001     -4.760      0.000      -0.004      -0.002
# X4             1.4724      0.178      8.295      0.000       1.123       1.821
# X5           221.7823     39.612      5.599      0.000     143.901     299.664
# X6            38.6385     44.030      0.878      0.381     -47.927     125.204
# ==============================================================================
# Omnibus:                       67.452   Durbin-Watson:                   2.022
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              192.667
# Skew:                           0.794   Prob(JB):                     1.45e-42
# Kurtosis:                       6.031   Cond. No.                     2.41e+07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.41e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
y_pred=res.fittedvalues
e=df['Y']-y_pred
plt.scatter(df['X2'], e ,c="green")
plt.plot([df['X2'].min(), df['X2'].max()], [0, 0], linewidth=2);

# %%
plt.scatter(df['X3'], e ,c="green")
plt.plot([df['X3'].min(), df['X3'].max()], [0, 0], linewidth=2);

# %%
plt.scatter(df['X4'], e ,c="green")
plt.plot([df['X4'].min(), df['X4'].max()], [0, 0], linewidth=2);

# %%
plt.scatter(df['X5'], e ,c="green")
plt.plot([df['X5'].min(), df['X5'].max()], [0, 0], linewidth=2);

# %%
plt.scatter(df['X6'], e ,c="green")
plt.plot([df['X6'].min(), df['X6'].max()], [0, 0], linewidth=2)

# %%
plt.scatter(df['X6'], df['Y'])

# %%
plt.scatter(np.log(df['X6']), df['Y'])

# %%
plt.scatter(np.log(df['X6']), np.log(df['Y']))

# %%
plt.scatter(df['X3'], df['Y'])

# %%
plt.scatter(df['X3'], np.log(df['Y']))

# %%
plt.scatter(np.log(df['X3']), df['Y'])

# %%
mod = ols("Y~logX2+X3+X3+X4+X5+X6",data=df)
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      Y   R-squared:                       0.635
# Model:                            OLS   Adj. R-squared:                  0.631
# Method:                 Least Squares   F-statistic:                     135.5
# Date:                Thu, 22 Apr 2021   Prob (F-statistic):           6.80e-83
# Time:                        10:14:21   Log-Likelihood:                -1364.1
# No. Observations:                 395   AIC:                             2740.
# Df Residuals:                     389   BIC:                             2764.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -1.046e+04   5478.115     -1.910      0.057   -2.12e+04     309.751
# logX2         -3.2100      0.490     -6.549      0.000      -4.174      -2.246
# X3            -0.0030      0.001     -4.589      0.000      -0.004      -0.002
# X4             1.4025      0.175      8.003      0.000       1.058       1.747
# X5           231.4335     39.148      5.912      0.000     154.465     308.402
# X6            38.8809     43.387      0.896      0.371     -46.421     124.183
# ==============================================================================
# Omnibus:                       68.479   Durbin-Watson:                   2.034
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              193.100
# Skew:                           0.811   Prob(JB):                     1.17e-42
# Kurtosis:                       6.017   Cond. No.                     2.41e+07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.41e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
y_pred=res.fittedvalues
e=df['Y']-y_pred
plt.scatter(df['logX2'], e ,c="green")
plt.plot([df['logX2'].min(), df['logX2'].max()], [0, 0], linewidth=2);

# %%
plt.scatter(df['X3'], e ,c="green")
plt.plot([df['X3'].min(), df['X3'].max()], [0, 0], linewidth=2);

# %%
plt.scatter(df['X4'], e ,c="green")
plt.plot([df['X4'].min(), df['X4'].max()], [0, 0], linewidth=2);

# %%
plt.scatter(df['X5'], e ,c="green")
plt.plot([df['X5'].min(), df['X5'].max()], [0, 0], linewidth=2);

# %%
plt.scatter(df['X6'], e ,c="green")
plt.plot([df['X6'].min(), df['X6'].max()], [0, 0], linewidth=2)

# %%
mod = ols("Y~logX2+logX3+X3+X4+X5+X6",data=df)
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      Y   R-squared:                       0.694
# Model:                            OLS   Adj. R-squared:                  0.689
# Method:                 Least Squares   F-statistic:                     146.5
# Date:                Thu, 22 Apr 2021   Prob (F-statistic):           1.87e-96
# Time:                        10:14:23   Log-Likelihood:                -1329.5
# No. Observations:                 395   AIC:                             2673.
# Df Residuals:                     388   BIC:                             2701.
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -1.789e+04   5099.765     -3.508      0.001   -2.79e+04   -7862.157
# logX2         -2.6320      0.455     -5.788      0.000      -3.526      -1.738
# logX3         -6.3654      0.739     -8.608      0.000      -7.819      -4.911
# X3             0.0016      0.001      1.971      0.049    4.12e-06       0.003
# X4             0.6483      0.183      3.541      0.000       0.288       1.008
# X5           304.5906     36.910      8.252      0.000     232.021     377.160
# X6            85.2783     40.171      2.123      0.034       6.298     164.258
# ==============================================================================
# Omnibus:                       94.865   Durbin-Watson:                   2.012
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              424.340
# Skew:                           0.959   Prob(JB):                     7.17e-93
# Kurtosis:                       7.701   Cond. No.                     2.44e+07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.44e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
y_pred=res.fittedvalues
e=df['Y']-y_pred
plt.scatter(df['logX2'], e ,c="green")
plt.plot([df['logX2'].min(), df['logX2'].max()], [0, 0], linewidth=2);

# %%
plt.scatter(df['logX3'], e ,c="green")
plt.plot([df['logX3'].min(), df['logX3'].max()], [0, 0], linewidth=2);

# %%
plt.scatter(df['X4'], e ,c="green")
plt.plot([df['X4'].min(), df['X4'].max()], [0, 0], linewidth=2);

# %%
plt.scatter(df['X5'], e ,c="green")
plt.plot([df['X5'].min(), df['X5'].max()], [0, 0], linewidth=2);

# %%
plt.scatter(df['X6'], e ,c="green")
plt.plot([df['X6'].min(), df['X6'].max()], [0, 0], linewidth=2)

# %%
mod = ols("logY~logX2+logX3+X4+X5+X6",data=df)
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   logY   R-squared:                       0.722
# Model:                            OLS   Adj. R-squared:                  0.718
# Method:                 Least Squares   F-statistic:                     201.9
# Date:                Thu, 22 Apr 2021   Prob (F-statistic):          1.06e-105
# Time:                        10:14:23   Log-Likelihood:                 69.243
# No. Observations:                 395   AIC:                            -126.5
# Df Residuals:                     389   BIC:                            -102.6
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   -606.6425    106.591     -5.691      0.000    -816.209    -397.076
# logX2         -0.0757      0.013     -5.774      0.000      -0.101      -0.050
# logX3         -0.1441      0.016     -9.002      0.000      -0.176      -0.113
# X4             0.0166      0.005      3.128      0.002       0.006       0.027
# X5            10.1865      0.964     10.571      0.000       8.292      12.081
# X6             2.9367      0.892      3.293      0.001       1.183       4.690
# ==============================================================================
# Omnibus:                      110.319   Durbin-Watson:                   2.009
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1704.959
# Skew:                          -0.714   Prob(JB):                         0.00
# Kurtosis:                      13.077   Cond. No.                     1.29e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.29e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
y_pred=res.fittedvalues
e=df['logY']-y_pred
plt.scatter(df['logX2'], e ,c="green")
plt.plot([df['logX2'].min(), df['logX2'].max()], [0, 0], linewidth=2);

# %%
plt.scatter(df['logX3'], e ,c="green")
plt.plot([df['logX3'].min(), df['logX3'].max()], [0, 0], linewidth=2);

# %%
plt.scatter(df['X4'], e ,c="green")
plt.plot([df['X4'].min(), df['X4'].max()], [0, 0], linewidth=2);

# %%
plt.scatter(df['X5'], e ,c="green")
plt.plot([df['X5'].min(), df['X5'].max()], [0, 0], linewidth=2);

# %%
plt.scatter(df['X6'], e ,c="green")
plt.plot([df['X6'].min(), df['X6'].max()], [0, 0], linewidth=2)

# %%
plt.figure(figsize=(12, 6))
plt.scatter(np.log(df['X6']), df['X5'])
